# %% [markdown]
# # Subject: Data Science Foundation
#
# ## Session 13 - Correlation in Python.
#
# ### Assignment 1 -  Calculating Correlation for pandas Dataframe "Titanic"
#
#
# - Considering the Correlation analysis presented in Demo 1 develop a new one for the data set “Titanic”.
# - Select the variables most appropriate and justify your option.
# - Commit scripts in your GitHub account. You should export your your solution code (.ipynb notebook) and push it to your repository “DataScienceFoundations”.
# - The following are the tasks that should complete and synchronize with your repository “DataScienceFoundations” until November 23. Please notice that this task will not be graded, however it’s important that you correctly understand and complete them in order to be sure that you won’t have problems with further assignments.
#
# Guidelines:
# - Clone the Git repository to get an initial code:
# https://github.com/FGutierresBTS/BTS_MasterInBigData.git
# - Once you downloaded the repository to your local file system, go to the folder “BTS_MasterInBigData/ Session_13_DSF”.
# - Copy the folder “Session_13_DSF” into your local folder “DataScienceFoundations”.
# - In the folder “Session_13_DSF” you will see the files called:
#     -	BTS_DataScienceFoundations_Session13_Correlation_Individual_assignment.ipynb.
#     -   "1_titanic_dataset.csv" (note: this dataset must be pre-processed).
# - Import these files into Jupyter Notebook using the “Upload” button.
# - Open the imported script and put your code inside the notebook.
# - Export your Assignment *.ipynb notebook and push it to your repository “DataScienceFoundations”.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("/Users/roman2006/Documents/GitHub/BTS_DataScienceFoundations/Session_13_DSF/1_titanic_dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['gender']= df['Sex'].map({'male':0,
             'female':1})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       0
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       1
# 3      0            113803  53.1000  C123        S       1
# ...

# %%
df['Embarked'].values
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'S', 'S',
#        'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'Q', 'S', 'S', 'S',
#        'C', 'S', 'Q', 'S', 'C', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S',
#        'C', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'Q', 'C', 'S', 'S', 'S',
#        'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', nan, 'S', 'S', 'C',
#        'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'C', 'S', 'S', 'C', 'S', 'Q',
#        'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'C', 'Q', 'S', 'C', 'S',
#        'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
# ...

# %%
df['port']= df['Embarked'].map({'S':0,
             'C':1, 'Q':3})

# %%
df.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col0 {
#             background-color:  #b40426;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col1 {
#             background-color:  #4a63d3;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col2 {
#             background-color:  #4257c9;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col3 {
#             background-color:  #5875e1;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col5 {
#             background-color:  #4c66d6;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col6 {
#             background-color:  #485fd1;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col7 {
#             background-color:  #3f53c6;
#         }    #T_94e6f0d4_d091_11e7_875d_8c859036ef18row0_col8 {
#             background-color:  #445acc;
# ...

# %%
df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col0 {
#             background-color:  #b40426;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col1 {
#             background-color:  #4961d2;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col2 {
#             background-color:  #4055c8;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col3 {
#             background-color:  #5572df;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col5 {
#             background-color:  #4a63d3;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col6 {
#             background-color:  #4e68d8;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col7 {
#             background-color:  #3e51c5;
#         }    #T_84e9e34c_d091_11e7_ab48_8c859036ef18row0_col8 {
#             background-color:  #4055c8;
# ...

# %% [markdown]
# ### As we can see, there is apparently no real relation with survived other than gender being positive, wich it means it favors women. Other factors don't appear to be critical in the idea.
