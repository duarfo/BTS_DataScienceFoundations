# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn import datasets
# Out:
# /Users/roman2006/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df =pd.read_csv('/Users/roman2006/PycharmProjects/Liana Clone/Session_2/3_bike_sharing.csv')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# ### What is the average bike rental?

# %%
df["count"].mean()
# Out:
# 191.57413191254824

# %% [markdown]
# ### Knowledge learned: 191.5 bikes per day

# %% [markdown]
# ### Is there an important Variation?

# %%
df['count'].min()
# Out:
# 1

# %%
df['count'].max()
# Out:
# 977

# %% [markdown]
# ### Knowledged learned: There is a huge variation on bike rentals

# %% [markdown]
# ### Is there a correlation between total bike rentals and workdays?

# %%
plt.figure(figsize=[12,10])
sns.barplot('workingday', 'count', data=df)
plt.show()

# %% [markdown]
# ### Knowledge learned: There is no significant difference in total bike rental.

# %% [markdown]
# ### Is There a correlation between the number of registered bike rentals and work days?

# %%
plt.figure(figsize=[12,10])
sns.barplot('workingday', 'registered', data=df)
plt.show()

# %% [markdown]
# ### Knowledge learned: There appears to be a relation but not that strong

# %% [markdown]
# ### Is There a correlation between the number of casual bike rentals and work days?

# %%
plt.figure(figsize=[12,10])
sns.barplot('workingday', 'casual', data=df)
plt.show()

# %% [markdown]
# ### Knowledge learned: There is an increase in casual rentals on non workdays.

# %% [markdown]
# ### Knowledege learned: The huge variation isn't explained with workdays, the minimun and maximums can be outliers or can be explained by other relationships

# %% [markdown]
# ### Is there a relationship between holidays and all type of bike rentals?

# %%
plt.figure(figsize=[12,10])
sns.barplot('holiday', 'registered', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('holiday', 'casual', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('holiday', 'count', data=df)
plt.show()

# %% [markdown]
# ### Knowledged learned: There is an important variation in holidays and bike rentals.

# %% [markdown]
# ### Is there a relation between weather and all types of rentals?

# %%
plt.figure(figsize=[12,10])
sns.barplot('weather', 'registered', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('weather', 'casual', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('weather', 'count', data=df)
plt.show()

# %% [markdown]
# ### knowledge learned: Weather affects greatly in the number of casual rentals.

# %% [markdown]
# ### Is there a relationship between season and all types of rentals?

# %%
plt.figure(figsize=[12,10])
sns.barplot('season', 'count', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('season', 'casual', data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.barplot('season', 'registered', data=df)
plt.show()

# %% [markdown]
# ### Knowledged learned: The season greatly affects the number of bike rentals, especially casual rentals, they all seem to decrease in spring.

# %%
g = sns.FacetGrid(df, col= 'season')
g.map(sns.distplot, 'count')
plt.show()

# %% [markdown]
# ### Knowledge found: we can see that that bike rentals on spring tend mpre to 0
